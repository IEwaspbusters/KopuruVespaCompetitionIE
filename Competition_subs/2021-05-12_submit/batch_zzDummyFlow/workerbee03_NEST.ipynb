# %% [markdown]
# ## import modules

# %%
# Data manipulation and scientific computing -----------------------------------
import pandas as pd
import numpy as np

# %% [markdown]
# ## get the data

# %%
QUEEN = pd.read_csv('../../../Input_open_data/ds02_datos-nidos-avispa-asiatica.csv', sep=',')

# %%
QUEEN.head()
# Out:
#    _id  URTEA/ANIO  JARDUERA_ZENBAKIA/NUM_ACTUACION ALTA_DATA/FECHA ALTA  \
# 0    1        2019                              214  2019-07-06 00:00:00
# 1    2        2019                               22  2019-03-25 00:00:00
# 2    3        2019                              434  2019-08-07 00:00:00
# 3    4        2019                              565  2019-07-20 00:00:00
# 4    5        2019                              766  2019-06-08 00:00:00
#
#   ERABILTZAILEA_EU/USUARIO_EU ERABILTZAILEA_CAS/USUARIO_CAS  \
# 0             ABADIÑOKO UDALA          AYUNTAMIENTO ABADIÑO
# 1                     BASALAN                       BASALAN
# 2             ABADIÑOKO UDALA          AYUNTAMIENTO ABADIÑO
# 3             ABADIÑOKO UDALA          AYUNTAMIENTO ABADIÑO
# 4             ABADIÑOKO UDALA          AYUNTAMIENTO ABADIÑO
#
#   UDALERRIA/MUNICIPIO     HELBIDEA/DIRECCION  ESPEZIE/ESPECIE  \
# 0             ABADIÑO                 OLALDE  AVISPA ASIÁTICA
# ...

# %%
GEO = pd.read_csv('./WBds01_GEO.csv', sep=',')
GEO.head()
# Out:
#    Unnamed: 0 CODIGO  ESTACION TIPO    XUTM     YUTM  cota (m)
# 0           0   C076  Abetxuko    A  527154  4747039       510
# 1           1   C056   Alegria    A  538992  4743676       545
# 2           2   C035    Altube    M  510880  4757063       618
# 3           3   C0A3  Antoñana    A  549965  4725290       573
# 4           4   C001   Arkaute    M  530608  4744631       517

# %%
METEO = pd.read_csv('./WBds02_METEO.csv', sep=',')
METEO.head()
# Out:
#    Unnamed: 0  COD.  ESTACION  cota (m)  ENE  FEB  MAR             ABR  MAY  \
# 0           0   NaN       NaN       NaN  NaN  NaN  NaN  DÍAS DE HELADA  NaN
# 1           1  KOD.  ESTAZIOA  kota (m)  URT  OTS  MAR             API  MAI
# 2           2  C076  Abetxuko       510    9    9    3               3    0
# 3           3  C056   Alegria       545    8    9    3               3    1
# 4           4  C035    Altube       618    5    4    0               3    1
#
#    JUN  JUL  AGO  SET  OCT  NOV  DIC    SUMA
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN     NaN
# 1  EKA  UZT  ABU  IRA  URR  AZA  ABE  BATURA
# 2    0    0    0    0    1    2   10      37
# 3    0    0    0    0    2    3   13      42
# 4    0    0    0    0    0    0    6      19

# %% [markdown]
# ## do the python magic

# %%
QUEENtrain = QUEEN.loc[:,['HELBIDEA/DIRECCION']]

# %%
QUEENpredict = QUEEN .loc[:,['ESPEZIE/ESPECIE']]

# %% [markdown]
# ## Export the data

# %%
QUEENtrain.to_csv('WBds03_QUEENtrain.csv')

# %%
QUEENpredict.to_csv('WBds03_QUEENpredict.csv')
